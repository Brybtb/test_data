# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df = pd.read_csv('S&P_500_Researcher_Dataset_1979_-_2018.csv', squeeze=True, parse_dates=True)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.set_index('Ticker', inplace=True)

# %%
df.axes
# Out:
# [Index(['A', 'AA', 'AAL', 'AAL (Alex)', 'AAP', 'AAPL', 'ABBV', 'ABC',
#         'ABC (Bro.)', 'ABI',
#         ...
#         'MSCI', 'ABMD', 'EVRG', 'TWTR', 'FLT', 'HFC', 'BR', 'CPRT', 'ANET',
#         'WCG'],
#        dtype='object', name='Ticker', length=1405),
#  Index(['Company Name', '3/31/1979', '6/30/1979', '9/30/1979', '12/31/1979',
#         '3/31/1980', '6/30/1980', '9/30/1980', '12/31/1980', '3/31/1981',
#         ...
#         '12/31/2017', '1/31/2018', '2/28/2018', '3/31/2018', '4/30/2018',
#         '5/31/2018', '6/30/2018', '7/31/2018', '8/31/2018', '9/30/2018'],
#        dtype='object', length=270)]

# %%
df
# Out:
#                                   Company Name 3/31/1979 6/30/1979 9/30/1979  \
# Ticker
# A                    Agilent Technologies Inc.       NaN       NaN       NaN
# AA                                   Alcoa Inc  1,909.12  1,804.77  2,070.04
# AAL                    American Airlines Group       NaN       NaN       NaN
# AAL (Alex)               Alexander & Alexander       NaN       NaN       NaN
# AAP                     Advance Auto Parts Inc       NaN       NaN       NaN
# AAPL                                Apple Inc.       NaN       NaN       NaN
# ABBV                               AbbVie Inc.       NaN       NaN       NaN
# ABC                    AmerisourceBergen Corp.       NaN       NaN       NaN
# ABC (Bro.)       American Broadcasting Cos Inc    950.06  1,142.92  1,276.01
# ABI                    Applied Biosystems Inc.    637.51    579.11    589.62
# ABK                 Ambac Financial Group Inc.       NaN       NaN       NaN
# ...

# %%
# raw = df.swapaxes()
# raw.head(2)

# %%
# Out:
# Ticker
# A             object
# AA            object
# AAL           object
# AAL (Alex)    object
# AAP           object
# AAPL          object
# ABBV          object
# ABC           object
# ABC (Bro.)    object
# ABI           object
# ABK           object
# ABS           object
# ABT           object
# ABX           object
# ACAS          object
# ACF           object
# ACK           object
# ACN           object
# ACS           object
# ACV           object
# ACY           object
# AD            object
# ADBE          object
# ADCT          object
# ADI           object
# ADM           object
# ADP           object
# ADPT          object
# ADS           object
# ADSK          object
#                ...
# DXC           object
# RE            object
# ALGN          object
# ANSS          object
# INFO          object
# CDNS          object
# SBAC          object
# IQV           object
# BHF           object
# MGM           object
# RMD           object
# PKG           object
# ...
