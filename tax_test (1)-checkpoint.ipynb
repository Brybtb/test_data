# %% [markdown]
# # View of Dividends in Accounts

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# %matplotlib notebook

# %%
# Read tax_test.csv
account_info = 'tax_test.csv'
tax_test = pd.read_csv(account_info, encoding = 'utf-8')

# %%
# Strip whitespace/regex
tax_test.columns = tax_test.columns.str.replace("\r", "")

tax_test.columns = tax_test.columns.str.replace("\n", "")

# %%
# Strip out commas
tax_test['Dollar DividendAmount'] = tax_test['Dollar DividendAmount'].str.replace(',', '')

# %%
# Change Dollar Dividend Amount to numeric
tax_test['Dollar DividendAmount'] = pd.to_numeric(tax_test['Dollar DividendAmount'])

# %%
# Create a new series using 'AccountType'
accounts = tax_test.groupby(['AccountType'])

# %%
# Create a new series with dividend totals
div_totals = accounts['Dollar DividendAmount'].sum()

# %%
# Create DataFrame off of groupby
div_per_account = pd.DataFrame(accounts['Dollar DividendAmount'].sum())

# %%
# Reset index to make 'AccountType a column'
div_per_account = div_per_account.reset_index()
div_per_account.head()
# Out:
#     AccountType  Dollar DividendAmount
# 0    Tax-Exempt                5149.33
# 1  Tax_Deferred                6814.80
# 2       Taxable               11177.02

# %%
# Chart our data, give it a title, and label the axes
div_chart = div_totals.plot(kind="bar", title="Divs")
div_chart.set_xlabel("Account Type")
div_chart.set_ylabel("Dollars")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Set new index to 'AccountType'
div_sum = div_per_account.set_index("AccountType")
div_sum
# Out:
#               Dollar DividendAmount
# AccountType
# Tax-Exempt                  5149.33
# Tax_Deferred                6814.80
# Taxable                    11177.02

# %%
# div_total = div_sum.pd.DataFrame.loc['Taxable', 'Dollar DividendAmount']

# # Grab the data contained within the "Berry" row and the "Phone Number" column

# %%
# Calculate taxes paid from divs and remaining for cash for reinvestment
div_sum['tax_paid'] = div_sum['Dollar DividendAmount'] * .2
div_sum['tax_retained'] = div_sum['Dollar DividendAmount'] * .8

# %%
div_sum.head(3)
# Out:
#               Dollar DividendAmount  tax_paid  tax_retained
# AccountType
# Tax-Exempt                  5149.33  1029.866      4119.464
# Tax_Deferred                6814.80  1362.960      5451.840
# Taxable                    11177.02  2235.404      8941.616

# %%
div_chart = div_sum.plot(kind="bar", title="Divs")
div_chart.set_xlabel("Account Type")
div_chart.set_ylabel("Dollars")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
var = div_sum.groupby(['tax_paid', 'tax_drag']).AccountType.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-1417bc2ae9e1> in <module>()
# ----> 1 var = div_sum.groupby(['tax_paid', 'tax_drag']).AccountType.sum()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
# --> 765                              (type(self).__name__, attr))
#     766
#     767     @Substitution(klass='GroupBy',
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'AccountType'

# %%
# It is also possible to group a DataFrame by multiple columns
# This returns an object with multiple indexes, however, which can be harder to deal with
grouped_international_data = clean_ufo_df.groupby(['country', 'state'])

# Converting a GroupBy object into a DataFrame
international_duration = pd.DataFrame(
    grouped_international_data["duration (seconds)"].sum())
international_duration.head(10)
